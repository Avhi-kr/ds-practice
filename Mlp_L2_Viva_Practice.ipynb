# %% [markdown]
# <a href="https://colab.research.google.com/github/Avhi-kr/ds-practice/blob/main/Mlp_L2_Viva_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/DataPreprocessingGraded_dataset.csv')
df
# Out:
#        V1    V2       V3    V4        V5 Target
# 0     2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1     0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2       ?     ?   4000.0  35.0  NEGATIVE    YES
# 3       ?  20.0   5000.0  45.0  NEGATIVE    YES
# 4     1.0  24.0   6000.0  77.0  NEGATIVE     NO
# ..    ...   ...      ...   ...       ...    ...
# 743  23.0   2.0    500.0  38.0  NEGATIVE     NO
# 744  21.0   2.0    500.0  52.0  NEGATIVE     NO
# 745  23.0   3.0    750.0  62.0  NEGATIVE     NO
# 746  39.0   1.0    250.0  39.0  NEGATIVE     NO
# 747  72.0   1.0    250.0  72.0  NEGATIVE     NO
#
# [748 rows x 6 columns]

# %%
df.shape
# Out:
# (748, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      748 non-null    object
#  1   V2      748 non-null    object
#  2   V3      748 non-null    float64
#  3   V4      748 non-null    float64
#  4   V5      748 non-null    object
#  5   Target  748 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 35.2+ KB

# %%
df=df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      748 non-null    string
#  1   V2      748 non-null    string
#  2   V3      748 non-null    Int64
#  3   V4      748 non-null    Int64
#  4   V5      748 non-null    string
#  5   Target  748 non-null    string
# dtypes: Int64(2), string(4)
# memory usage: 36.7 KB

# %%
pd.Series({'total':(df['V1']=='?').sum().sum()})
# Out:
# total    0
# dtype: int64

# %%
df[['V1','V2']]=df[['V1','V2']].replace('?',np.nan)
df[['V1','V2']] = df[['V1','V2']].astype(float)
df
# Out:
#        V1    V2     V3  V4        V5 Target
# 0     2.0  50.0  12500  98  NEGATIVE    YES
# 1     0.0  13.0   3250  28  NEGATIVE    YES
# 2     0.0   0.0   4000  35  NEGATIVE    YES
# 3     0.0  20.0   5000  45  NEGATIVE    YES
# 4     1.0  24.0   6000  77  NEGATIVE     NO
# ..    ...   ...    ...  ..       ...    ...
# 743  23.0   2.0    500  38  NEGATIVE     NO
# 744  21.0   2.0    500  52  NEGATIVE     NO
# 745  23.0   3.0    750  62  NEGATIVE     NO
# 746  39.0   1.0    250  39  NEGATIVE     NO
# 747  72.0   1.0    250  72  NEGATIVE     NO
#
# [748 rows x 6 columns]

# %%
grt=df[df['V1']<=5]
grt
# Out:
#       V1    V2     V3  V4        V5 Target
# 0    2.0  50.0  12500  98  NEGATIVE    YES
# 1    0.0  13.0   3250  28  NEGATIVE    YES
# 2    0.0   0.0   4000  35  NEGATIVE    YES
# 3    0.0  20.0   5000  45  NEGATIVE    YES
# 4    1.0  24.0   6000  77  NEGATIVE     NO
# ..   ...   ...    ...  ..       ...    ...
# 653  4.0   2.0    500  30  NEGATIVE     NO
# 656  4.0   2.0    500  31  NEGATIVE     NO
# 669  2.0   3.0    750  75  NEGATIVE    YES
# 670  2.0   3.0    750  77  NEGATIVE     NO
# 681  4.0   2.0    500  46  NEGATIVE     NO
#
# [362 rows x 6 columns]

# %%
df.drop(df[df['V1']>5].index)
# Out:
#       V1    V2     V3  V4        V5 Target
# 0    2.0  50.0  12500  98  NEGATIVE    YES
# 1    0.0  13.0   3250  28  NEGATIVE    YES
# 2    0.0   0.0   4000  35  NEGATIVE    YES
# 3    0.0  20.0   5000  45  NEGATIVE    YES
# 4    1.0  24.0   6000  77  NEGATIVE     NO
# ..   ...   ...    ...  ..       ...    ...
# 653  4.0   2.0    500  30  NEGATIVE     NO
# 656  4.0   2.0    500  31  NEGATIVE     NO
# 669  2.0   3.0    750  75  NEGATIVE    YES
# 670  2.0   3.0    750  77  NEGATIVE     NO
# 681  4.0   2.0    500  46  NEGATIVE     NO
#
# [362 rows x 6 columns]

# %%
corr=np.corrcoef(df['V1'],df['V2'])
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df
# Out:
#        V1    V2       V3    V4        V5 Target
# 0     2.0  50.0  12500.0  98.0  NEGATIVE    YES
# 1     0.0  13.0   3250.0  28.0  NEGATIVE    YES
# 2     0.0   0.0   4000.0  35.0  NEGATIVE    YES
# 3     0.0  20.0   5000.0  45.0  NEGATIVE    YES
# 4     1.0  24.0   6000.0  77.0  NEGATIVE     NO
# ..    ...   ...      ...   ...       ...    ...
# 743  23.0   2.0    500.0  38.0  NEGATIVE     NO
# 744  21.0   2.0    500.0  52.0  NEGATIVE     NO
# 745  23.0   3.0    750.0  62.0  NEGATIVE     NO
# 746  39.0   1.0    250.0  39.0  NEGATIVE     NO
# 747  72.0   1.0    250.0  72.0  NEGATIVE     NO
#
# [748 rows x 6 columns]

# %%
df['sum of v1 & v2']=df['V1']+df['V2']
df
# Out:
#            V1    V2        V3        V4        V5 Target  sum of v1 & v2
# 0    0.027027  1.00  7.623346  2.615633  NEGATIVE    YES        1.027027
# 1    0.000000  0.26  1.282738 -0.257881  NEGATIVE    YES        0.260000
# 2    0.000000  0.00  1.796842  0.029471  NEGATIVE    YES        0.000000
# 3    0.000000  0.40  2.482313  0.439973  NEGATIVE    YES        0.400000
# 4    0.013514  0.48  3.167784  1.753579  NEGATIVE     NO        0.493514
# ..        ...   ...       ...       ...       ...    ...             ...
# 743  0.310811  0.04 -0.602307  0.152621  NEGATIVE     NO        0.350811
# 744  0.283784  0.04 -0.602307  0.727324  NEGATIVE     NO        0.323784
# 745  0.310811  0.06 -0.430940  1.137826  NEGATIVE     NO        0.370811
# 746  0.527027  0.02 -0.773675  0.193671  NEGATIVE     NO        0.547027
# 747  0.972973  0.02 -0.773675  1.548328  NEGATIVE     NO        0.992973
#
# [748 rows x 7 columns]

# %%
grt=pd.DataFrame([((df['V1']>5) | (df['V2']>30)).sum()],columns=['sum'])
grt
# Out:
#    sum
# 0  393

# %%
cor=np.corrcoef(df['V1'],df['V2'])
cor
# Out:
# array([[ 1.        , -0.17240062],
#        [-0.17240062,  1.        ]])

# %%
import seaborn as sns

# %%
sns.heatmap(cor)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler
doit=MinMaxScaler()
df[['V1','V2']]=doit.fit_transform(df[['V1','V2']])
df
# Out:
#            V1    V2       V3    V4        V5 Target
# 0    0.027027  1.00  12500.0  98.0  NEGATIVE    YES
# 1    0.000000  0.26   3250.0  28.0  NEGATIVE    YES
# 2    0.000000  0.00   4000.0  35.0  NEGATIVE    YES
# 3    0.000000  0.40   5000.0  45.0  NEGATIVE    YES
# 4    0.013514  0.48   6000.0  77.0  NEGATIVE     NO
# ..        ...   ...      ...   ...       ...    ...
# 743  0.310811  0.04    500.0  38.0  NEGATIVE     NO
# 744  0.283784  0.04    500.0  52.0  NEGATIVE     NO
# 745  0.310811  0.06    750.0  62.0  NEGATIVE     NO
# 746  0.527027  0.02    250.0  39.0  NEGATIVE     NO
# 747  0.972973  0.02    250.0  72.0  NEGATIVE     NO
#
# [748 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
task2=StandardScaler()
df[['V3','V4']]=task2.fit_transform(df[['V3','V4']])
df
# Out:
#            V1    V2        V3        V4        V5 Target
# 0    0.027027  1.00  7.623346  2.615633  NEGATIVE    YES
# 1    0.000000  0.26  1.282738 -0.257881  NEGATIVE    YES
# 2    0.000000  0.00  1.796842  0.029471  NEGATIVE    YES
# 3    0.000000  0.40  2.482313  0.439973  NEGATIVE    YES
# 4    0.013514  0.48  3.167784  1.753579  NEGATIVE     NO
# ..        ...   ...       ...       ...       ...    ...
# 743  0.310811  0.04 -0.602307  0.152621  NEGATIVE     NO
# 744  0.283784  0.04 -0.602307  0.727324  NEGATIVE     NO
# 745  0.310811  0.06 -0.430940  1.137826  NEGATIVE     NO
# 746  0.527027  0.02 -0.773675  0.193671  NEGATIVE     NO
# 747  0.972973  0.02 -0.773675  1.548328  NEGATIVE     NO
#
# [748 rows x 6 columns]

# %%
from sklearn.datasets import load_breast_cancer

# %%
df2=load_breast_cancer()
df3=load_breast_cancer()
df2
df2=pd.DataFrame(df2.data,columns=df2.feature_names)
df2.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
grt=pd.Series((df2['mean texture']>20).count())
grt
# Out:
# 0    569
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df3.data)

model = LogisticRegression(max_iter=2000)

select1 = RFE(model, n_features_to_select=2)
X_new = select1.fit_transform(X_scaled, df3.target)

print(df3.feature_names[select1.support_])
# Out:
# ['worst area' 'worst concave points']
