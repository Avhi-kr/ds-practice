# %% [markdown]
# <a href="https://colab.research.google.com/github/Avhi-kr/ds-practice/blob/main/MLP_practice_code_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
