# %% [markdown]
# <a href="https://colab.research.google.com/github/Avhi-kr/ds-practice/blob/main/PCA_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data_path="/content/heart.csv"
df=pd.read_csv(data_path)

# %%
df.shape
# Out:
# (918, 12)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease', 'z_score'],
#       dtype='object')

# %%
from scipy.stats import zscore
df['z_score']=zscore(df['RestingBP'])
df['z_score']
# Out:
# 0      0.410909
# 1      1.491752
# 2     -0.129513
# 3      0.302825
# 4      0.951331
#          ...
# 913   -1.210356
# 914    0.627078
# 915   -0.129513
# 916   -0.129513
# 917    0.302825
# Name: z_score, Length: 918, dtype: float64

# %%
outlier=df[df['z_score'].abs()>3]
print(outlier)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 449   55   M           NAP          0            0          0     Normal
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease   z_score
# 109    106              N      0.0       Up             0  3.113018
# 241    142              Y      2.0     Flat             1  3.653439
# 365    140              Y      1.0     Flat             1  3.653439
# ...
