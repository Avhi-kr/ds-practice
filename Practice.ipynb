# %% [markdown]
# <a href="https://colab.research.google.com/github/Avhi-kr/ds-practice/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("/content/canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.plot(df['year'], df['per capita income (US$)'])

plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.title("Year vs Per Capita Income")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(df['year'], df['per capita income (US$)'], marker='o')

plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.title("Growth of Per Capita Income Over Years")

plt.grid(True)

plt.show()

# %%
plt.scatter(df['year'], df['per capita income (US$)'])

plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.title("Year vs Per Capita Income")

plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
y_pred = reg.predict([[2020]])
print(y_pred)
# Out:
# [41288.69409442]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Plot
plt.scatter(df['year'], df['per capita income (US$)'])
plt.plot(df[['year']],prediction)

plt.xlabel("Year")
plt.ylabel("Per Capita Income")
plt.title("Linear Regression Fit")

plt.show()

# %%
print(df['year'].shape)
print(df[['year']].shape)
# Out:
# (47,)
# (47, 1)

# %%
df ['predicted_income']=prediction
df.to_csv("predicted.csv")
